# %%
import numpy as np
from scipy.linalg import svd
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error 
from sklearn.model_selection import GridSearchCV

# %%
# To start, I need to have a look at the data itself. I do this by adding the column names to a dataframe.
column_names = ['state', 'county', 'community', 'communityname', 'fold', 'population', 'householdsize', 'racepctblack', 'racePctWhite', 'racePctAsian', 'racePctHisp', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'numbUrban', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'perCapInc', 'whitePerCap', 'blackPerCap', 'indianPerCap', 'AsianPerCap', 'OtherPerCap', 'HispPerCap', 'NumUnderPov', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'NumIlleg', 'PctIlleg', 'NumImmig', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'RentLowQ', 'RentMedian', 'RentHighQ', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'NumInShelters', 'NumStreet', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps', 'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop', 'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol', 'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian', 'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz', 'PolicAveOTWorked', 'LandArea', 'PopDens', 'PctUsePubTrans', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr', 'LemasGangUnitDeploy', 'LemasPctOfficDrugUn', 'PolicBudgPerPop', 'ViolentCrimesPerPop']
data = pd.read_csv('data/communities.data', sep=',')
data.columns = column_names
data = data.replace('?', np.nan) #Replace '?' for NaN values so I can use built-in pandas functions.

# %%
data.head(10)
# Out:
#    state county community        communityname  fold  population  \
# 0     53    NaN       NaN          Tukwilacity     1        0.00
# 1     24    NaN       NaN         Aberdeentown     1        0.00
# 2     34      5     81440  Willingborotownship     1        0.04
# 3     42     95      6096    Bethlehemtownship     1        0.01
# 4      6    NaN       NaN    SouthPasadenacity     1        0.02
# 5     44      7     41500          Lincolntown     1        0.01
# 6      6    NaN       NaN            Selmacity     1        0.01
# 7     21    NaN       NaN        Hendersoncity     1        0.03
# 8     29    NaN       NaN          Claytoncity     1        0.01
# 9      6    NaN       NaN         DalyCitycity     1        0.13
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# 0           0.16          0.12          0.74          0.45  ...      0.02
# 1           0.42          0.49          0.56          0.17  ...      0.01
# 2           0.77          1.00          0.08          0.12  ...      0.02
# 3           0.55          0.02          0.95          0.09  ...      0.04
# 4           0.28          0.06          0.54          1.00  ...      0.01
# 5           0.39          0.00          0.98          0.06  ...      0.05
# 6           0.74          0.03          0.46          0.20  ...      0.01
# 7           0.34          0.20          0.84          0.02  ...      0.04
# 8           0.40          0.06          0.87          0.30  ...      0.00
# 9           0.71          0.15          0.07          1.00  ...      0.02
#
#    PopDens  PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# 0     0.12            0.45        NaN            NaN                  NaN
# 1     0.21            0.02        NaN            NaN                  NaN
# 2     0.39            0.28        NaN            NaN                  NaN
# 3     0.09            0.02        NaN            NaN                  NaN
# 4     0.58            0.10        NaN            NaN                  NaN
# 5     0.08            0.06        NaN            NaN                  NaN
# 6     0.33            0.00        NaN            NaN                  NaN
# 7     0.17            0.04        NaN            NaN                  NaN
# 8     0.47            0.11        NaN            NaN                  NaN
# 9     1.00            1.00        NaN            NaN                  NaN
#
#    LemasGangUnitDeploy  LemasPctOfficDrugUn  PolicBudgPerPop  \
# 0                  NaN                  0.0              NaN
# 1                  NaN                  0.0              NaN
# 2                  NaN                  0.0              NaN
# 3                  NaN                  0.0              NaN
# 4                  NaN                  0.0              NaN
# 5                  NaN                  0.0              NaN
# 6                  NaN                  0.0              NaN
# 7                  NaN                  0.0              NaN
# 8                  NaN                  0.0              NaN
# 9                  NaN                  0.0              NaN
#
#    ViolentCrimesPerPop
# 0                 0.67
# 1                 0.43
# 2                 0.12
# 3                 0.03
# 4                 0.14
# 5                 0.03
# 6                 0.55
# 7                 0.53
# 8                 0.15
# 9                 0.24
#
# [10 rows x 128 columns]

# %%
#Looking at the data to get a sense of what cleaning is needed.
#To start, the dataset includes a data description that notes which columns are predictive, so I will drop those columns.
dropped = ['state', 'county', 'community', 'communityname', 'fold']
data2 = data.drop(axis = 1, columns = dropped)
data2.info(verbose = True, show_counts = True)
data.info(verbose = True, show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 123 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    population             1993 non-null   float64
#  1    householdsize          1993 non-null   float64
#  2    racepctblack           1993 non-null   float64
#  3    racePctWhite           1993 non-null   float64
#  4    racePctAsian           1993 non-null   float64
#  5    racePctHisp            1993 non-null   float64
#  6    agePct12t21            1993 non-null   float64
#  7    agePct12t29            1993 non-null   float64
#  8    agePct16t24            1993 non-null   float64
#  9    agePct65up             1993 non-null   float64
#  10   numbUrban              1993 non-null   float64
#  11   pctUrban               1993 non-null   float64
#  12   medIncome              1993 non-null   float64
#  13   pctWWage               1993 non-null   float64
#  14   pctWFarmSelf           1993 non-null   float64
#  15   pctWInvInc             1993 non-null   float64
#  16   pctWSocSec             1993 non-null   float64
#  17   pctWPubAsst            1993 non-null   float64
#  18   pctWRetire             1993 non-null   float64
#  19   medFamInc              1993 non-null   float64
#  20   perCapInc              1993 non-null   float64
#  21   whitePerCap            1993 non-null   float64
#  22   blackPerCap            1993 non-null   float64
#  23   indianPerCap           1993 non-null   float64
#  24   AsianPerCap            1993 non-null   float64
#  25   OtherPerCap            1992 non-null   object
#  26   HispPerCap             1993 non-null   float64
#  27   NumUnderPov            1993 non-null   float64
#  28   PctPopUnderPov         1993 non-null   float64
#  29   PctLess9thGrade        1993 non-null   float64
#  30   PctNotHSGrad           1993 non-null   float64
#  31   PctBSorMore            1993 non-null   float64
#  32   PctUnemployed          1993 non-null   float64
#  33   PctEmploy              1993 non-null   float64
#  34   PctEmplManu            1993 non-null   float64
#  35   PctEmplProfServ        1993 non-null   float64
#  36   PctOccupManu           1993 non-null   float64
#  37   PctOccupMgmtProf       1993 non-null   float64
#  38   MalePctDivorce         1993 non-null   float64
#  39   MalePctNevMarr         1993 non-null   float64
#  40   FemalePctDiv           1993 non-null   float64
#  41   TotalPctDiv            1993 non-null   float64
#  42   PersPerFam             1993 non-null   float64
#  43   PctFam2Par             1993 non-null   float64
#  44   PctKids2Par            1993 non-null   float64
#  45   PctYoungKids2Par       1993 non-null   float64
#  46   PctTeen2Par            1993 non-null   float64
#  47   PctWorkMomYoungKids    1993 non-null   float64
#  48   PctWorkMom             1993 non-null   float64
#  49   NumIlleg               1993 non-null   float64
#  50   PctIlleg               1993 non-null   float64
#  51   NumImmig               1993 non-null   float64
#  52   PctImmigRecent         1993 non-null   float64
#  53   PctImmigRec5           1993 non-null   float64
#  54   PctImmigRec8           1993 non-null   float64
#  55   PctImmigRec10          1993 non-null   float64
#  56   PctRecentImmig         1993 non-null   float64
#  57   PctRecImmig5           1993 non-null   float64
#  58   PctRecImmig8           1993 non-null   float64
#  59   PctRecImmig10          1993 non-null   float64
#  60   PctSpeakEnglOnly       1993 non-null   float64
#  61   PctNotSpeakEnglWell    1993 non-null   float64
#  62   PctLargHouseFam        1993 non-null   float64
#  63   PctLargHouseOccup      1993 non-null   float64
#  64   PersPerOccupHous       1993 non-null   float64
#  65   PersPerOwnOccHous      1993 non-null   float64
#  66   PersPerRentOccHous     1993 non-null   float64
#  67   PctPersOwnOccup        1993 non-null   float64
#  68   PctPersDenseHous       1993 non-null   float64
#  69   PctHousLess3BR         1993 non-null   float64
#  70   MedNumBR               1993 non-null   float64
#  71   HousVacant             1993 non-null   float64
#  72   PctHousOccup           1993 non-null   float64
#  73   PctHousOwnOcc          1993 non-null   float64
#  74   PctVacantBoarded       1993 non-null   float64
#  75   PctVacMore6Mos         1993 non-null   float64
#  76   MedYrHousBuilt         1993 non-null   float64
#  77   PctHousNoPhone         1993 non-null   float64
#  78   PctWOFullPlumb         1993 non-null   float64
#  79   OwnOccLowQuart         1993 non-null   float64
#  80   OwnOccMedVal           1993 non-null   float64
#  81   OwnOccHiQuart          1993 non-null   float64
#  82   RentLowQ               1993 non-null   float64
#  83   RentMedian             1993 non-null   float64
#  84   RentHighQ              1993 non-null   float64
#  85   MedRent                1993 non-null   float64
#  86   MedRentPctHousInc      1993 non-null   float64
#  87   MedOwnCostPctInc       1993 non-null   float64
#  88   MedOwnCostPctIncNoMtg  1993 non-null   float64
#  89   NumInShelters          1993 non-null   float64
#  90   NumStreet              1993 non-null   float64
#  91   PctForeignBorn         1993 non-null   float64
#  92   PctBornSameState       1993 non-null   float64
#  93   PctSameHouse85         1993 non-null   float64
#  94   PctSameCity85          1993 non-null   float64
#  95   PctSameState85         1993 non-null   float64
#  96   LemasSwornFT           318 non-null    object
#  97   LemasSwFTPerPop        318 non-null    object
#  98   LemasSwFTFieldOps      318 non-null    object
#  99   LemasSwFTFieldPerPop   318 non-null    object
#  100  LemasTotalReq          318 non-null    object
#  101  LemasTotReqPerPop      318 non-null    object
#  102  PolicReqPerOffic       318 non-null    object
#  103  PolicPerPop            318 non-null    object
#  104  RacialMatchCommPol     318 non-null    object
#  105  PctPolicWhite          318 non-null    object
#  106  PctPolicBlack          318 non-null    object
#  107  PctPolicHisp           318 non-null    object
#  108  PctPolicAsian          318 non-null    object
#  109  PctPolicMinor          318 non-null    object
#  110  OfficAssgnDrugUnits    318 non-null    object
#  111  NumKindsDrugsSeiz      318 non-null    object
#  112  PolicAveOTWorked       318 non-null    object
#  113  LandArea               1993 non-null   float64
#  114  PopDens                1993 non-null   float64
#  115  PctUsePubTrans         1993 non-null   float64
#  116  PolicCars              318 non-null    object
#  117  PolicOperBudg          318 non-null    object
#  118  LemasPctPolicOnPatr    318 non-null    object
#  119  LemasGangUnitDeploy    318 non-null    object
#  120  LemasPctOfficDrugUn    1993 non-null   float64
#  121  PolicBudgPerPop        318 non-null    object
#  122  ViolentCrimesPerPop    1993 non-null   float64
# dtypes: float64(100), object(23)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 128 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    state                  1993 non-null   int64
#  1    county                 820 non-null    object
#  2    community              817 non-null    object
#  3    communityname          1993 non-null   object
#  4    fold                   1993 non-null   int64
#  5    population             1993 non-null   float64
#  6    householdsize          1993 non-null   float64
#  7    racepctblack           1993 non-null   float64
#  8    racePctWhite           1993 non-null   float64
#  9    racePctAsian           1993 non-null   float64
#  10   racePctHisp            1993 non-null   float64
#  11   agePct12t21            1993 non-null   float64
#  12   agePct12t29            1993 non-null   float64
#  13   agePct16t24            1993 non-null   float64
#  14   agePct65up             1993 non-null   float64
#  15   numbUrban              1993 non-null   float64
#  16   pctUrban               1993 non-null   float64
#  17   medIncome              1993 non-null   float64
#  18   pctWWage               1993 non-null   float64
#  19   pctWFarmSelf           1993 non-null   float64
#  20   pctWInvInc             1993 non-null   float64
#  21   pctWSocSec             1993 non-null   float64
#  22   pctWPubAsst            1993 non-null   float64
#  23   pctWRetire             1993 non-null   float64
#  24   medFamInc              1993 non-null   float64
#  25   perCapInc              1993 non-null   float64
#  26   whitePerCap            1993 non-null   float64
#  27   blackPerCap            1993 non-null   float64
#  28   indianPerCap           1993 non-null   float64
#  29   AsianPerCap            1993 non-null   float64
#  30   OtherPerCap            1992 non-null   object
#  31   HispPerCap             1993 non-null   float64
#  32   NumUnderPov            1993 non-null   float64
#  33   PctPopUnderPov         1993 non-null   float64
#  34   PctLess9thGrade        1993 non-null   float64
#  35   PctNotHSGrad           1993 non-null   float64
#  36   PctBSorMore            1993 non-null   float64
#  37   PctUnemployed          1993 non-null   float64
#  38   PctEmploy              1993 non-null   float64
#  39   PctEmplManu            1993 non-null   float64
#  40   PctEmplProfServ        1993 non-null   float64
#  41   PctOccupManu           1993 non-null   float64
#  42   PctOccupMgmtProf       1993 non-null   float64
#  43   MalePctDivorce         1993 non-null   float64
#  44   MalePctNevMarr         1993 non-null   float64
#  45   FemalePctDiv           1993 non-null   float64
#  46   TotalPctDiv            1993 non-null   float64
#  47   PersPerFam             1993 non-null   float64
#  48   PctFam2Par             1993 non-null   float64
#  49   PctKids2Par            1993 non-null   float64
#  50   PctYoungKids2Par       1993 non-null   float64
#  51   PctTeen2Par            1993 non-null   float64
#  52   PctWorkMomYoungKids    1993 non-null   float64
#  53   PctWorkMom             1993 non-null   float64
#  54   NumIlleg               1993 non-null   float64
#  55   PctIlleg               1993 non-null   float64
#  56   NumImmig               1993 non-null   float64
#  57   PctImmigRecent         1993 non-null   float64
#  58   PctImmigRec5           1993 non-null   float64
#  59   PctImmigRec8           1993 non-null   float64
#  60   PctImmigRec10          1993 non-null   float64
#  61   PctRecentImmig         1993 non-null   float64
#  62   PctRecImmig5           1993 non-null   float64
#  63   PctRecImmig8           1993 non-null   float64
#  64   PctRecImmig10          1993 non-null   float64
#  65   PctSpeakEnglOnly       1993 non-null   float64
#  66   PctNotSpeakEnglWell    1993 non-null   float64
#  67   PctLargHouseFam        1993 non-null   float64
#  68   PctLargHouseOccup      1993 non-null   float64
#  69   PersPerOccupHous       1993 non-null   float64
#  70   PersPerOwnOccHous      1993 non-null   float64
#  71   PersPerRentOccHous     1993 non-null   float64
#  72   PctPersOwnOccup        1993 non-null   float64
#  73   PctPersDenseHous       1993 non-null   float64
#  74   PctHousLess3BR         1993 non-null   float64
#  75   MedNumBR               1993 non-null   float64
#  76   HousVacant             1993 non-null   float64
#  77   PctHousOccup           1993 non-null   float64
#  78   PctHousOwnOcc          1993 non-null   float64
#  79   PctVacantBoarded       1993 non-null   float64
#  80   PctVacMore6Mos         1993 non-null   float64
#  81   MedYrHousBuilt         1993 non-null   float64
#  82   PctHousNoPhone         1993 non-null   float64
#  83   PctWOFullPlumb         1993 non-null   float64
#  84   OwnOccLowQuart         1993 non-null   float64
#  85   OwnOccMedVal           1993 non-null   float64
#  86   OwnOccHiQuart          1993 non-null   float64
#  87   RentLowQ               1993 non-null   float64
#  88   RentMedian             1993 non-null   float64
#  89   RentHighQ              1993 non-null   float64
#  90   MedRent                1993 non-null   float64
#  91   MedRentPctHousInc      1993 non-null   float64
#  92   MedOwnCostPctInc       1993 non-null   float64
#  93   MedOwnCostPctIncNoMtg  1993 non-null   float64
#  94   NumInShelters          1993 non-null   float64
#  95   NumStreet              1993 non-null   float64
#  96   PctForeignBorn         1993 non-null   float64
#  97   PctBornSameState       1993 non-null   float64
#  98   PctSameHouse85         1993 non-null   float64
#  99   PctSameCity85          1993 non-null   float64
#  100  PctSameState85         1993 non-null   float64
#  101  LemasSwornFT           318 non-null    object
#  102  LemasSwFTPerPop        318 non-null    object
#  103  LemasSwFTFieldOps      318 non-null    object
#  104  LemasSwFTFieldPerPop   318 non-null    object
#  105  LemasTotalReq          318 non-null    object
#  106  LemasTotReqPerPop      318 non-null    object
#  107  PolicReqPerOffic       318 non-null    object
#  108  PolicPerPop            318 non-null    object
#  109  RacialMatchCommPol     318 non-null    object
#  110  PctPolicWhite          318 non-null    object
#  111  PctPolicBlack          318 non-null    object
#  112  PctPolicHisp           318 non-null    object
#  113  PctPolicAsian          318 non-null    object
#  114  PctPolicMinor          318 non-null    object
#  115  OfficAssgnDrugUnits    318 non-null    object
#  116  NumKindsDrugsSeiz      318 non-null    object
#  117  PolicAveOTWorked       318 non-null    object
#  118  LandArea               1993 non-null   float64
#  119  PopDens                1993 non-null   float64
#  120  PctUsePubTrans         1993 non-null   float64
#  121  PolicCars              318 non-null    object
#  122  PolicOperBudg          318 non-null    object
#  123  LemasPctPolicOnPatr    318 non-null    object
#  124  LemasGangUnitDeploy    318 non-null    object
#  125  LemasPctOfficDrugUn    1993 non-null   float64
#  126  PolicBudgPerPop        318 non-null    object
#  127  ViolentCrimesPerPop    1993 non-null   float64
# dtypes: float64(100), int64(2), object(26)
# memory usage: 1.9+ MB

# %%
# Since the columns missing data are missing more than 50% of the data from the other columns, 
#    I will drop them for now to ensure that I have enough data for a robust analysis.
dropped = ['OtherPerCap', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps', 'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop', 'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol', 'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian', 'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz', 'PolicAveOTWorked', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr', 'LemasGangUnitDeploy', 'PolicBudgPerPop']
data3 = data2.drop(axis = 1, columns = dropped)
data3.info(verbose = True, show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 100 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   population             1993 non-null   float64
#  1   householdsize          1993 non-null   float64
#  2   racepctblack           1993 non-null   float64
#  3   racePctWhite           1993 non-null   float64
#  4   racePctAsian           1993 non-null   float64
#  5   racePctHisp            1993 non-null   float64
#  6   agePct12t21            1993 non-null   float64
#  7   agePct12t29            1993 non-null   float64
#  8   agePct16t24            1993 non-null   float64
#  9   agePct65up             1993 non-null   float64
#  10  numbUrban              1993 non-null   float64
#  11  pctUrban               1993 non-null   float64
#  12  medIncome              1993 non-null   float64
#  13  pctWWage               1993 non-null   float64
#  14  pctWFarmSelf           1993 non-null   float64
#  15  pctWInvInc             1993 non-null   float64
#  16  pctWSocSec             1993 non-null   float64
#  17  pctWPubAsst            1993 non-null   float64
#  18  pctWRetire             1993 non-null   float64
#  19  medFamInc              1993 non-null   float64
#  20  perCapInc              1993 non-null   float64
#  21  whitePerCap            1993 non-null   float64
#  22  blackPerCap            1993 non-null   float64
#  23  indianPerCap           1993 non-null   float64
#  24  AsianPerCap            1993 non-null   float64
#  25  HispPerCap             1993 non-null   float64
#  26  NumUnderPov            1993 non-null   float64
#  27  PctPopUnderPov         1993 non-null   float64
#  28  PctLess9thGrade        1993 non-null   float64
#  29  PctNotHSGrad           1993 non-null   float64
#  30  PctBSorMore            1993 non-null   float64
#  31  PctUnemployed          1993 non-null   float64
#  32  PctEmploy              1993 non-null   float64
#  33  PctEmplManu            1993 non-null   float64
#  34  PctEmplProfServ        1993 non-null   float64
#  35  PctOccupManu           1993 non-null   float64
#  36  PctOccupMgmtProf       1993 non-null   float64
#  37  MalePctDivorce         1993 non-null   float64
#  38  MalePctNevMarr         1993 non-null   float64
#  39  FemalePctDiv           1993 non-null   float64
#  40  TotalPctDiv            1993 non-null   float64
#  41  PersPerFam             1993 non-null   float64
#  42  PctFam2Par             1993 non-null   float64
#  43  PctKids2Par            1993 non-null   float64
#  44  PctYoungKids2Par       1993 non-null   float64
#  45  PctTeen2Par            1993 non-null   float64
#  46  PctWorkMomYoungKids    1993 non-null   float64
#  47  PctWorkMom             1993 non-null   float64
#  48  NumIlleg               1993 non-null   float64
#  49  PctIlleg               1993 non-null   float64
#  50  NumImmig               1993 non-null   float64
#  51  PctImmigRecent         1993 non-null   float64
#  52  PctImmigRec5           1993 non-null   float64
#  53  PctImmigRec8           1993 non-null   float64
#  54  PctImmigRec10          1993 non-null   float64
#  55  PctRecentImmig         1993 non-null   float64
#  56  PctRecImmig5           1993 non-null   float64
#  57  PctRecImmig8           1993 non-null   float64
#  58  PctRecImmig10          1993 non-null   float64
#  59  PctSpeakEnglOnly       1993 non-null   float64
#  60  PctNotSpeakEnglWell    1993 non-null   float64
#  61  PctLargHouseFam        1993 non-null   float64
#  62  PctLargHouseOccup      1993 non-null   float64
#  63  PersPerOccupHous       1993 non-null   float64
#  64  PersPerOwnOccHous      1993 non-null   float64
#  65  PersPerRentOccHous     1993 non-null   float64
#  66  PctPersOwnOccup        1993 non-null   float64
#  67  PctPersDenseHous       1993 non-null   float64
#  68  PctHousLess3BR         1993 non-null   float64
#  69  MedNumBR               1993 non-null   float64
#  70  HousVacant             1993 non-null   float64
#  71  PctHousOccup           1993 non-null   float64
#  72  PctHousOwnOcc          1993 non-null   float64
#  73  PctVacantBoarded       1993 non-null   float64
#  74  PctVacMore6Mos         1993 non-null   float64
#  75  MedYrHousBuilt         1993 non-null   float64
#  76  PctHousNoPhone         1993 non-null   float64
#  77  PctWOFullPlumb         1993 non-null   float64
#  78  OwnOccLowQuart         1993 non-null   float64
#  79  OwnOccMedVal           1993 non-null   float64
#  80  OwnOccHiQuart          1993 non-null   float64
#  81  RentLowQ               1993 non-null   float64
#  82  RentMedian             1993 non-null   float64
#  83  RentHighQ              1993 non-null   float64
#  84  MedRent                1993 non-null   float64
#  85  MedRentPctHousInc      1993 non-null   float64
#  86  MedOwnCostPctInc       1993 non-null   float64
#  87  MedOwnCostPctIncNoMtg  1993 non-null   float64
#  88  NumInShelters          1993 non-null   float64
#  89  NumStreet              1993 non-null   float64
#  90  PctForeignBorn         1993 non-null   float64
#  91  PctBornSameState       1993 non-null   float64
#  92  PctSameHouse85         1993 non-null   float64
#  93  PctSameCity85          1993 non-null   float64
#  94  PctSameState85         1993 non-null   float64
#  95  LandArea               1993 non-null   float64
#  96  PopDens                1993 non-null   float64
#  97  PctUsePubTrans         1993 non-null   float64
#  98  LemasPctOfficDrugUn    1993 non-null   float64
#  99  ViolentCrimesPerPop    1993 non-null   float64
# dtypes: float64(100)
# memory usage: 1.5 MB

# %%
# I want to know initially if there are any features that are highly correlated to my target feature
corr_matrix = data3.corr()
corr_matrix['ViolentCrimesPerPop'].sort_values().drop(columns = ['ViolentCrimesPerPop'], axis = 0)
# Out:
# PctKids2Par           -0.738445
# PctFam2Par            -0.706713
# racePctWhite          -0.684787
# PctYoungKids2Par      -0.666094
# PctTeen2Par           -0.661598
#                          ...
# FemalePctDiv           0.556472
# pctWPubAsst            0.574690
# racepctblack           0.631279
# PctIlleg               0.737965
# ViolentCrimesPerPop    1.000000
# Name: ViolentCrimesPerPop, Length: 100, dtype: float64

# %%
# Now all of my columns are numeric, and they have enough data for analysis.
# Nest I need to separate the target value from the other columns and start my analysis.

# %%
X = data3.drop(['ViolentCrimesPerPop'], axis = 1)
y = data3['ViolentCrimesPerPop']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# To start, I want a baseline for my regression, so I fit a simple linear regression with standard settings.
model = LinearRegression().fit(X_train, y_train)

# %%
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print('Train score: ' + str(train_score))
print('Test score:  ' + str(test_score))
# From this simple regression, I can see that accuracy is decent for real world data that is hard to understand.
# Training data is significantly lower than train data, so overfitting is an issue.
# Out:
# Train score: 0.691832128893537
# Test score:  0.6765794475472465

# %%
#Performing a Lasso regression and analyzing the results.
lasso_pipe = Pipeline([('poly_features', PolynomialFeatures()), ('lasso', Lasso())])
parameters = {'poly_features__degree':[1, 2, 3]}
lasso_grid = GridSearchCV(lasso_pipe, param_grid = parameters).fit(X_train, y_train)

# %%
#Get the best score across the parameters.
lasso_best_score = lasso_grid.best_score_

# %%
#Performing a Ridge regression and analyzing the results.
ridge_pipe = Pipeline([('poly_features', PolynomialFeatures()), ('ridge', Ridge())])
parameters = {'poly_features__degree':[1, 2, 3]}
ridge_grid = GridSearchCV(ridge_pipe, param_grid = parameters).fit(X_train, y_train)

# %%
#Get the best score across the parameters.
ridge_best_score = lasso_grid.best_score_

# %%
print("Lasso best score: " + str(lasso_best_score))
print("Ridge best score: " + str(ridge_best_score))
# Out:
# Lasso best score: -0.003449826517250676
# Ridge best score: -0.003449826517250676
